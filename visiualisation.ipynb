# %%
import pandas as pd
import ast

# %%
df = pd.read_csv('merged_file.csv')
df = df.drop_duplicates()
df = df.dropna(subset=['Language'])
df['contributors'] = df['contributors'].replace("['The history or contributor list is too large to list contributors for this repository via the API.']", "[]")
df['Topics'] = df['Topics'].apply(ast.literal_eval)
df['languages'] = df['languages'].apply(ast.literal_eval)
df['contributors'] = df['contributors'].apply(ast.literal_eval)
df
# Out:
#                       Name                                        Description
# 0             freeCodeCamp  freeCodeCamp.org's open-source codebase and cu...  \
# 5              public-apis                     A collective list of free APIs
# 6        developer-roadmap  Interactive roadmaps, guides and other educati...
# 7     system-design-primer  Learn how to design large-scale systems. Prep ...
# 8                    react     The library for web and native user interfaces
# ...                    ...                                                ...
# 2698             editor.js        A block-style editor with clean JSON output
# 2699               Hystrix  Hystrix is a latency and fault tolerance libra...
# 2700         awesome-swift  A collaborative list of awesome Swift librarie...
# 2701                   pkg    Package your Node.js project into an executable
# 2702              jellyfin                     The Free Software Media System
#
#        Stars                                                URL
# 0     369549       https://github.com/freeCodeCamp/freeCodeCamp  \
# 5     247051         https://github.com/public-apis/public-apis
# 6     243636  https://github.com/kamranahmedse/developer-roa...
# 7     223929  https://github.com/donnemartin/system-design-p...
# 8     210013                  https://github.com/facebook/react
# ...      ...                                                ...
# 2698   23467            https://github.com/codex-team/editor.js
# 2699   23465                 https://github.com/Netflix/Hystrix
# 2700   23463      https://github.com/matteocrippa/awesome-swift
# 2701   23454                      https://github.com/vercel/pkg
# 2702   23444               https://github.com/jellyfin/jellyfin
#
#              Date creation  Dernier modification  Forks    Language
# 0     2014-12-24T17:49:19Z  2023-07-06T10:34:34Z  32806  TypeScript  \
# 5     2016-03-20T23:49:42Z  2023-07-06T10:46:14Z  28345      Python
# 6     2017-03-15T13:45:52Z  2023-07-06T10:42:38Z  34240  TypeScript
# 7     2017-02-26T16:15:28Z  2023-07-06T10:35:11Z  39662      Python
# 8     2013-05-24T16:15:54Z  2023-07-06T10:36:32Z  43969  JavaScript
# ...                    ...                   ...    ...         ...
# 2698  2015-11-28T20:56:35Z  2023-07-06T10:04:56Z   1791  TypeScript
# 2699  2012-11-19T20:14:46Z  2023-07-06T06:42:21Z   4710        Java
# 2700  2014-07-10T14:04:09Z  2023-07-06T06:29:10Z   3051        Ruby
# 2701  2016-08-08T19:41:59Z  2023-07-06T10:29:54Z   1005  JavaScript
# 2702  2018-12-09T06:36:45Z  2023-07-06T10:33:34Z   2147          C#
#
#                                                  Topics
# 0     [careers, certification, community, curriculum...  \
# 5     [api, apis, dataset, development, free, list, ...
# 6     [angular-roadmap, backend-roadmap, blockchain-...
# 7     [design, design-patterns, design-system, devel...
# 8     [declarative, frontend, javascript, library, r...
# ...                                                 ...
# 2698  [codex-editor, editor, javascript, json, redac...
# 2699                                                 []
# 2700  [awesome, awesome-list, awesome-lists, awesome...
# 2701                  [binaries, cli, compiler, nodejs]
# 2702          [csharp, dotnet, hacktoberfest, jellyfin]
#
#                                               languages
# 0     [TypeScript, JavaScript, CSS, MDX, Dockerfile,...  \
# 5                                       [Python, Shell]
# 6                  [TypeScript, Astro, JavaScript, CSS]
# 7                                       [Python, Shell]
# 8     [JavaScript, HTML, CSS, C++, TypeScript, Coffe...
# ...                                                 ...
# 2698                [TypeScript, HTML, CSS, JavaScript]
# 2699                       [Java, Clojure, CSS, Groovy]
# 2700                                             [Ruby]
# 2701  [JavaScript, TypeScript, CSS, HTML, Pug, Coffe...
# 2702       [C#, Shell, HTML, Dockerfile, Makefile, CSS]
#
#                                            contributors
# 0     [{'login': 'raisedadead', 'contributions': 142...
# 5     [{'login': 'matheusfelipeog', 'contributions':...
# 6     [{'login': 'kamranahmedse', 'contributions': 1...
# 7     [{'login': 'donnemartin', 'contributions': 175...
# 8     [{'login': 'zpao', 'contributions': 1778, 'typ...
# ...                                                 ...
# 2698  [{'login': 'khaydarov', 'contributions': 202, ...
# 2699  [{'login': 'mattrjacobs', 'contributions': 538...
# 2700  [{'login': 'READMEbot', 'contributions': 733, ...
# 2701  [{'login': 'igorklopov', 'contributions': 887,...
# 2702  [{'login': 'LukePulverenti', 'contributions': ...
#
# [2313 rows x 11 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Description', 'Stars', 'URL', 'Date creation',
#        'Dernier modification', 'Forks', 'Language', 'Topics', 'languages',
#        'contributors'],
#       dtype='object')

# %%
df_sorted = df.sort_values(by='Stars', ascending=False)
df_sorted

top_n = 10
df_top = df_sorted.head(top_n)

df_top
# Out:
#                        Name
# 0              freeCodeCamp  \
# 5               public-apis
# 6         developer-roadmap
# 7      system-design-primer
# 8                     react
# 10                      vue
# 11               tensorflow
# 12           awesome-python
# 1113  javascript-algorithms
# 13    javascript-algorithms
#
#                                             Description   Stars
# 0     freeCodeCamp.org's open-source codebase and cu...  369549  \
# 5                        A collective list of free APIs  247051
# 6     Interactive roadmaps, guides and other educati...  243636
# 7     Learn how to design large-scale systems. Prep ...  223929
# 8        The library for web and native user interfaces  210013
# 10    This is the repo for Vue 2. For Vue 3, go to h...  204327
# 11    An Open Source Machine Learning Framework for ...  175942
# 12    A curated list of awesome Python frameworks, l...  173065
# 1113  📝 Algorithms and data structures implemented i...  172057
# 13    📝 Algorithms and data structures implemented i...  172056
#
#                                                     URL         Date creation
# 0          https://github.com/freeCodeCamp/freeCodeCamp  2014-12-24T17:49:19Z  \
# 5            https://github.com/public-apis/public-apis  2016-03-20T23:49:42Z
# 6     https://github.com/kamranahmedse/developer-roa...  2017-03-15T13:45:52Z
# 7     https://github.com/donnemartin/system-design-p...  2017-02-26T16:15:28Z
# 8                     https://github.com/facebook/react  2013-05-24T16:15:54Z
# 10                         https://github.com/vuejs/vue  2013-07-29T03:24:51Z
# 11             https://github.com/tensorflow/tensorflow  2015-11-07T01:19:20Z
# 12              https://github.com/vinta/awesome-python  2014-06-27T21:00:06Z
# 1113  https://github.com/trekhleb/javascript-algorithms  2018-03-24T07:47:04Z
# 13    https://github.com/trekhleb/javascript-algorithms  2018-03-24T07:47:04Z
#
#       Dernier modification  Forks    Language
# 0     2023-07-06T10:34:34Z  32806  TypeScript  \
# 5     2023-07-06T10:46:14Z  28345      Python
# 6     2023-07-06T10:42:38Z  34240  TypeScript
# 7     2023-07-06T10:35:11Z  39662      Python
# 8     2023-07-06T10:36:32Z  43969  JavaScript
# 10    2023-07-06T10:27:41Z  34050  TypeScript
# 11    2023-07-06T10:44:25Z  88652         C++
# 12    2023-07-06T10:34:45Z  23481      Python
# 1113  2023-07-06T10:48:57Z  28259  JavaScript
# 13    2023-07-06T10:08:09Z  28259  JavaScript
#
#                                                  Topics
# 0     [careers, certification, community, curriculum...  \
# 5     [api, apis, dataset, development, free, list, ...
# 6     [angular-roadmap, backend-roadmap, blockchain-...
# 7     [design, design-patterns, design-system, devel...
# 8     [declarative, frontend, javascript, library, r...
# 10               [framework, frontend, javascript, vue]
# 11    [deep-learning, deep-neural-networks, distribu...
# 12    [awesome, collections, python, python-framewor...
# 1113  [algorithm, algorithms, computer-science, data...
# 13    [algorithm, algorithms, computer-science, data...
#
#                                               languages
# 0     [TypeScript, JavaScript, CSS, MDX, Dockerfile,...  \
# 5                                       [Python, Shell]
# 6                  [TypeScript, Astro, JavaScript, CSS]
# 7                                       [Python, Shell]
# 8     [JavaScript, HTML, CSS, C++, TypeScript, Coffe...
# 10           [TypeScript, JavaScript, HTML, CSS, Shell]
# 11    [C++, Python, MLIR, Starlark, HTML, Go, C, Jav...
# 12                                   [Python, Makefile]
# 1113                                [JavaScript, Shell]
# 13                                  [JavaScript, Shell]
#
#                                            contributors
# 0     [{'login': 'raisedadead', 'contributions': 142...
# 5     [{'login': 'matheusfelipeog', 'contributions':...
# 6     [{'login': 'kamranahmedse', 'contributions': 1...
# 7     [{'login': 'donnemartin', 'contributions': 175...
# 8     [{'login': 'zpao', 'contributions': 1778, 'typ...
# 10    [{'login': 'yyx990803', 'contributions': 2553,...
# 11    [{'login': 'tensorflower-gardener', 'contribut...
# 12    [{'login': 'vinta', 'contributions': 951, 'typ...
# 1113  [{'login': 'trekhleb', 'contributions': 827, '...
# 13    [{'login': 'trekhleb', 'contributions': 827, '...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Remove rows with NaN in the Language column
df2 = df.dropna(subset=['Language'])

# Count the number of occurrences for each language
language_counts = df2['Language'].value_counts().head(15)

# Plotting the pie chart
plt.figure(figsize=(8, 8))
language_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Language Distribution')
plt.ylabel('')
plt.show()

# %%
# Sort the dataframe by 'Stars' column in descending order
df3 = df.sort_values(by='Stars', ascending=False)

# Get the top 10 languages based on stars
top_languages = df3.head(50)['Language']
# print(top_languages)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
top_languages.value_counts().plot(kind='bar')
plt.title('Top 10 Popular Languages by Stars')
plt.xlabel('Language')
plt.ylabel('Number of Repositories')
plt.xticks(rotation=45)
plt.show()

# %%
# Remove rows with NaN in the Language column

# Sort the dataframe by 'Forks' column in descending order
df4 = df.sort_values(by='Forks', ascending=False)

# Get the top 10 languages based on forks
top_languages = df4.head(20)['Language']

# Count the number of repositories for each language
language_counts = top_languages.value_counts()

# Plotting the bar plot
plt.figure(figsize=(10, 6))
language_counts.plot(kind='bar')
plt.title('Popular Languages by Forks')
plt.xlabel('Language')
plt.ylabel('Number of Repositories')
plt.xticks(rotation=45)
plt.show()

# %%
# Sort the dataframe by the number of contributors in descending order
df['Num Contributors'] = df['contributors'].apply(lambda x: len(x))
df5 = df.sort_values(by='Num Contributors', ascending=False)

# Get the top 10 languages based on contributors
top_languages = df5.head(10)['Language']

# Plotting the bar chart
plt.figure(figsize=(10, 6))
top_languages.value_counts().plot(kind='bar')
plt.title('Top 10 Popular Languages by Contributors')
plt.xlabel('Language')
plt.ylabel('Number of Contributors')
plt.xticks(rotation=45)
plt.show()

# %%
from wordcloud import WordCloud
import ast


# Flatten the topics column
topics = [topic for sublist in df['Topics'] for topic in sublist]

# Create a string of all topics
topics_text = ' '.join(topics)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(topics_text)

# Plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud of Repository Topics')
plt.axis('off')
plt.show()

# %%
from wordcloud import WordCloud


# Flatten the topics column
topics = [topic for sublist in df['languages'] for topic in sublist]

# Create a string of all topics
topics_text = ' '.join(topics)

# Generate the word cloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(topics_text)

# Plot the word cloud
plt.figure(figsize=(10, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.title('Word Cloud of Repository languages')
plt.axis('off')
plt.show()

# %%
# Compter le nombre d'occurrences de chaque langue dans la colonne 'Language'
language_counts = df.groupby('Language').size()

# Trier les comptages par ordre décroissant
language_counts_sorted = language_counts.sort_values(ascending=False)

# Afficher les 20 premières occurrences de langues les plus fréquentes
top_20_language = language_counts_sorted.head(10)
# top_20_language

# %%
# Convertir la colonne 'Date creation' en objets datetime en utilisant le format spécifié
df['Date creation'] = pd.to_datetime(df['Date creation'], format='%Y-%m-%dT%H:%M:%SZ')

# Obtenir les années distinctes
distinct_years = df['Date creation'].dt.year.unique()
distinct_years = sorted(distinct_years)

# %%
line_data = []
for language, count in top_20_language.items():
    per_years = []
    for year in distinct_years:
        # Convert 'Date creation' column to datetime format
        df['Date creation'] = pd.to_datetime(df['Date creation'])

        # Filter the dataframe for the desired year (2012 in this example)
        df_2012 = df[df['Date creation'].dt.year == year]

        # Specify the language you want to count
        target_language = language

        # Filter the dataframe to include only rows with the target language
        df_target_language = df_2012[df_2012['Language'] == target_language]

        # Count the occurrences of the target language
        language_count = len(df_target_language)

#         print(f"Count of {target_language} in {year}: {language_count}")
        per_years.append(language_count)
        
    line_data.append([language,per_years])

# %%
data = line_data

# Extract the language names and count data
languages = [item[0] for item in data]
counts = [item[1] for item in data]

# Plotting the line chart
plt.figure(figsize=(12, 6))

for i in range(len(languages)):
    plt.plot(distinct_years,counts[i], label=languages[i])

plt.xlabel('Years')
plt.ylabel('Count')
plt.title('Language Counts Over Time')
plt.legend()
plt.grid(True)

plt.show()

# %%
df['Stars'] = pd.to_numeric(df['Stars'])
df['Forks'] = pd.to_numeric(df['Forks'])
df['Sum_Stars_Forks'] = df['Stars'] + df['Forks']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming you have a DataFrame called 'df' with columns 'Language' and 'Sum_Stars_Forks'
top_languages = df.groupby('Language')['Sum_Stars_Forks'].sum().nlargest(10)

# Plotting the bar chart
plt.figure(figsize=(10, 6))
top_languages.plot(kind='bar')
plt.xlabel('Language')
plt.ylabel('Sum of Stars and Forks')
plt.title('Top 10 Languages by Sum of Stars and Forks')
plt.show()

# %%
df
# Out:
#                       Name                                        Description
# 0             freeCodeCamp  freeCodeCamp.org's open-source codebase and cu...  \
# 5              public-apis                     A collective list of free APIs
# 6        developer-roadmap  Interactive roadmaps, guides and other educati...
# 7     system-design-primer  Learn how to design large-scale systems. Prep ...
# 8                    react     The library for web and native user interfaces
# ...                    ...                                                ...
# 2698             editor.js        A block-style editor with clean JSON output
# 2699               Hystrix  Hystrix is a latency and fault tolerance libra...
# 2700         awesome-swift  A collaborative list of awesome Swift librarie...
# 2701                   pkg    Package your Node.js project into an executable
# 2702              jellyfin                     The Free Software Media System
#
#        Stars                                                URL
# 0     369549       https://github.com/freeCodeCamp/freeCodeCamp  \
# 5     247051         https://github.com/public-apis/public-apis
# 6     243636  https://github.com/kamranahmedse/developer-roa...
# 7     223929  https://github.com/donnemartin/system-design-p...
# 8     210013                  https://github.com/facebook/react
# ...      ...                                                ...
# 2698   23467            https://github.com/codex-team/editor.js
# 2699   23465                 https://github.com/Netflix/Hystrix
# 2700   23463      https://github.com/matteocrippa/awesome-swift
# 2701   23454                      https://github.com/vercel/pkg
# 2702   23444               https://github.com/jellyfin/jellyfin
#
#            Date creation  Dernier modification  Forks    Language
# 0    2014-12-24 17:49:19  2023-07-06T10:34:34Z  32806  TypeScript  \
# 5    2016-03-20 23:49:42  2023-07-06T10:46:14Z  28345      Python
# 6    2017-03-15 13:45:52  2023-07-06T10:42:38Z  34240  TypeScript
# 7    2017-02-26 16:15:28  2023-07-06T10:35:11Z  39662      Python
# 8    2013-05-24 16:15:54  2023-07-06T10:36:32Z  43969  JavaScript
# ...                  ...                   ...    ...         ...
# 2698 2015-11-28 20:56:35  2023-07-06T10:04:56Z   1791  TypeScript
# 2699 2012-11-19 20:14:46  2023-07-06T06:42:21Z   4710        Java
# 2700 2014-07-10 14:04:09  2023-07-06T06:29:10Z   3051        Ruby
# 2701 2016-08-08 19:41:59  2023-07-06T10:29:54Z   1005  JavaScript
# 2702 2018-12-09 06:36:45  2023-07-06T10:33:34Z   2147          C#
#
#                                                  Topics
# 0     [careers, certification, community, curriculum...  \
# 5     [api, apis, dataset, development, free, list, ...
# 6     [angular-roadmap, backend-roadmap, blockchain-...
# 7     [design, design-patterns, design-system, devel...
# 8     [declarative, frontend, javascript, library, r...
# ...                                                 ...
# 2698  [codex-editor, editor, javascript, json, redac...
# 2699                                                 []
# 2700  [awesome, awesome-list, awesome-lists, awesome...
# 2701                  [binaries, cli, compiler, nodejs]
# 2702          [csharp, dotnet, hacktoberfest, jellyfin]
#
#                                               languages
# 0     [TypeScript, JavaScript, CSS, MDX, Dockerfile,...  \
# 5                                       [Python, Shell]
# 6                  [TypeScript, Astro, JavaScript, CSS]
# 7                                       [Python, Shell]
# 8     [JavaScript, HTML, CSS, C++, TypeScript, Coffe...
# ...                                                 ...
# 2698                [TypeScript, HTML, CSS, JavaScript]
# 2699                       [Java, Clojure, CSS, Groovy]
# 2700                                             [Ruby]
# 2701  [JavaScript, TypeScript, CSS, HTML, Pug, Coffe...
# 2702       [C#, Shell, HTML, Dockerfile, Makefile, CSS]
#
#                                            contributors  Num Contributors
# 0     [{'login': 'raisedadead', 'contributions': 142...                30  \
# 5     [{'login': 'matheusfelipeog', 'contributions':...                30
# 6     [{'login': 'kamranahmedse', 'contributions': 1...                30
# 7     [{'login': 'donnemartin', 'contributions': 175...                30
# 8     [{'login': 'zpao', 'contributions': 1778, 'typ...                30
# ...                                                 ...               ...
# 2698  [{'login': 'khaydarov', 'contributions': 202, ...                30
# 2699  [{'login': 'mattrjacobs', 'contributions': 538...                30
# 2700  [{'login': 'READMEbot', 'contributions': 733, ...                30
# 2701  [{'login': 'igorklopov', 'contributions': 887,...                30
# 2702  [{'login': 'LukePulverenti', 'contributions': ...                30
#
#       Sum_Stars_Forks
# 0              402355
# 5              275396
# 6              277876
# 7              263591
# 8              253982
# ...               ...
# 2698            25258
# 2699            28175
# 2700            26514
# 2701            24459
# 2702            25591
#
# [2313 rows x 13 columns]

# %%
df['annee_creation'] = pd.DatetimeIndex(df['Date creation']).year
new_df = df1 = df[['contributors','annee_creation']][(df['annee_creation'] >= 2020)]

max_contributors = {}

for index, row in new_df.iterrows():
    contributors = row['contributors']
    if len(contributors):
        for contributor in contributors:
            login = contributor['login']
            contributions = contributor['contributions']
            if login not in max_contributors:
                max_contributors[login] = contributions
            else :
                max_contributors[login] = max_contributors[login] + contributions

# %%
sorted_dict = {k: v for k, v in sorted(max_contributors.items(), key=lambda item: item[1], reverse=True)[:20]}

names = list(sorted_dict.keys())
values = list(sorted_dict.values())

plt.bar(names, values)
plt.xticks(rotation=90)
plt.xlabel('User')
plt.ylabel('Count')
plt.title('Top contributors')

plt.show()
